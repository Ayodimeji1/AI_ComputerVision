# %% [markdown]
# ## Face Detection

# %% [markdown]
# #### Install all necessary dependencies

# %%
# !pip install tensorflow mtcnn opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.9 MB 3.0 MB/s eta 0:00:01
#    -------- ------------------------------- 0.4/1.9 MB 5.0 MB/s eta 0:00:01
#    --------------- ------------------------ 0.7/1.9 MB 5.9 MB/s eta 0:00:01
#    ------------------------ --------------- 1.2/1.9 MB 6.7 MB/s eta 0:00:01
#    --------------------------------- ------ 1.6/1.9 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 6.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#     --------------------------------------- 0.7/38.8 MB 15.0 MB/s eta 0:00:03
#    - -------------------------------------- 1.3/38.8 MB 13.3 MB/s eta 0:00:03
#    -- ------------------------------------- 1.9/38.8 MB 13.7 MB/s eta 0:00:03
# ...

# %% [markdown]
# #### Import necessary libraries

# %%
from mtcnn import MTCNN
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# #### Initialise face detection model

# %%
detector = MTCNN()

def detect_faces(image_path):
    # Read the image
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Detect faces
    results = detector.detect_faces(image_rgb)
    
    # Draw bounding boxes around detected faces
    for result in results:
        x, y, width, height = result['box']
        cv2.rectangle(image_rgb, (x, y), (x + width, y + height), (0, 255, 0), 2)
    
    # Display the image
    plt.imshow(image_rgb)
    plt.axis('off')
    plt.show()

# %% [markdown]
# #### Test model

# %%
detect_faces('C:/Users/ayodi/Documents/Deep Learning/ComputerVision/ibmcoference.jpg')
